# %%
import pandas as pd
import numpy as np
import math as m

# %%
df = pd.read_csv("../data/Superstore_2023.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                9994 non-null   object
#  1   City                    9994 non-null   object
#  2   Country/Region          9994 non-null   object
#  3   Customer ID             9994 non-null   object
#  4   Customer Name           9994 non-null   object
#  5   Order Date              9994 non-null   object
#  6   Order ID                9994 non-null   object
#  7   Order Profitable?       9994 non-null   object
#  8   Postal Code             9983 non-null   float64
#  9   Product ID              9994 non-null   object
#  10  Product Name            9994 non-null   object
#  11  Region                  9994 non-null   object
#  12  Row ID                  9994 non-null   int64
#  13  Segment                 9994 non-null   object
#  14  Ship Date               9994 non-null   object
#  15  Ship Mode               9994 non-null   object
#  16  Ship Status             9994 non-null   object
#  17  State                   9994 non-null   object
#  18  Sub-Category            9994 non-null   object
#  19  Days to Ship Actual     9994 non-null   int64
#  20  Days to Ship Scheduled  9994 non-null   int64
#  21  Discount                9994 non-null   object
#  22  Profit                  9994 non-null   int64
#  23  Quantity                9994 non-null   int64
#  24  Sales                   9994 non-null   int64
#  25  Sales Forecast          9994 non-null   int64
# dtypes: float64(1), int64(7), object(18)
# memory usage: 2.0+ MB

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           Category             City Country/Region Customer ID  \
# 0        Furniture        Henderson  United States    CG-12520
# 1        Furniture        Henderson  United States    CG-12520
# 2  Office Supplies      Los Angeles  United States    DV-13045
# 3        Furniture  Fort Lauderdale  United States    SO-20335
# 4  Office Supplies  Fort Lauderdale  United States    SO-20335
#
#      Customer Name  Order Date        Order ID Order Profitable?  Postal Code  \
# 0      Claire Gute   8/11/2021  CA-2021-152156        Profitable      42420.0
# 1      Claire Gute   8/11/2021  CA-2021-152156        Profitable      42420.0
# 2  Darrin Van Huff  12/06/2021  CA-2021-138688        Profitable      90036.0
# 3   Sean O'Donnell  11/10/2020  US-2020-108966      Unprofitable      33311.0
# 4   Sean O'Donnell  11/10/2020  US-2020-108966      Unprofitable      33311.0
#
#         Product ID                                       Product Name Region  \
# 0  FUR-BO-10001798                  Bush Somerset Collection Bookcase  South
# 1  FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs,...  South
# 2  OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...   West
# 3  FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table  South
# 4  OFF-ST-10000760                     Eldon Fold 'N Roll Cart System  South
#
#    Row ID    Segment   Ship Date       Ship Mode      Ship Status       State  \
# 0       1   Consumer  11/11/2021    Second Class  Shipped On Time    Kentucky
# 1       2   Consumer  11/11/2021    Second Class  Shipped On Time    Kentucky
# 2       3  Corporate  16/06/2021    Second Class     Shipped Late  California
# 3       4   Consumer  18/10/2020  Standard Class     Shipped Late     Florida
# 4       5   Consumer  18/10/2020  Standard Class     Shipped Late     Florida
#
#   Sub-Category  Days to Ship Actual  Days to Ship Scheduled Discount  Profit  \
# 0    Bookcases                    3                       3    0.00%      42
# 1       Chairs                    3                       3    0.00%     220
# 2       Labels                    4                       3    0.00%       7
# 3       Tables                    7                       6   45.00%    -383
# 4      Storage                    7                       6   20.00%       3
#
#    Quantity  Sales  Sales Forecast
# 0         2    262             392
# 1         3    732            1096
# 2         2     15              22
# 3         5    958            1434
# 4         2     22              33

# %%
# Eliminar columnas

df = df.drop(['Customer ID','Order ID','Postal Code','Product ID','Row ID'], axis = 1)

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#           Category             City Country/Region    Customer Name  \
# 0        Furniture        Henderson  United States      Claire Gute
# 1        Furniture        Henderson  United States      Claire Gute
# 2  Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3        Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4  Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
# 5        Furniture      Los Angeles  United States  Brosina Hoffman
# 6  Office Supplies      Los Angeles  United States  Brosina Hoffman
# 7       Technology      Los Angeles  United States  Brosina Hoffman
# 8  Office Supplies      Los Angeles  United States  Brosina Hoffman
# 9  Office Supplies      Los Angeles  United States  Brosina Hoffman
#
#    Order Date Order Profitable?  \
# 0   8/11/2021        Profitable
# 1   8/11/2021        Profitable
# 2  12/06/2021        Profitable
# 3  11/10/2020      Unprofitable
# 4  11/10/2020      Unprofitable
# 5   9/06/2019        Profitable
# 6   9/06/2019        Profitable
# 7   9/06/2019        Profitable
# 8   9/06/2019        Profitable
# 9   9/06/2019        Profitable
#
#                                         Product Name Region    Segment  \
# 0                  Bush Somerset Collection Bookcase  South   Consumer
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  South   Consumer
# 2  Self-Adhesive Address Labels for Typewriters b...   West  Corporate
# 3      Bretford CR4500 Series Slim Rectangular Table  South   Consumer
# 4                     Eldon Fold 'N Roll Cart System  South   Consumer
# 5  Eldon Expressions Wood and Plastic Desk Access...   West   Consumer
# 6                                         Newell 322   West   Consumer
# 7                     Mitel 5320 IP Phone VoIP phone   West   Consumer
# 8  DXL Angle-View Binders with Locking Rings by S...   West   Consumer
# 9                   Belkin F5C206VTEL 6 Outlet Surge   West   Consumer
#
#     Ship Date       Ship Mode      Ship Status       State Sub-Category  \
# 0  11/11/2021    Second Class  Shipped On Time    Kentucky    Bookcases
# 1  11/11/2021    Second Class  Shipped On Time    Kentucky       Chairs
# 2  16/06/2021    Second Class     Shipped Late  California       Labels
# 3  18/10/2020  Standard Class     Shipped Late     Florida       Tables
# 4  18/10/2020  Standard Class     Shipped Late     Florida      Storage
# 5  14/06/2019  Standard Class    Shipped Early  California  Furnishings
# 6  14/06/2019  Standard Class    Shipped Early  California          Art
# 7  14/06/2019  Standard Class    Shipped Early  California       Phones
# 8  14/06/2019  Standard Class    Shipped Early  California      Binders
# 9  14/06/2019  Standard Class    Shipped Early  California   Appliances
#
#    Days to Ship Actual  Days to Ship Scheduled Discount  Profit  Quantity  \
# 0                    3                       3    0.00%      42         2
# 1                    3                       3    0.00%     220         3
# 2                    4                       3    0.00%       7         2
# 3                    7                       6   45.00%    -383         5
# 4                    7                       6   20.00%       3         2
# 5                    5                       6    0.00%      14         7
# 6                    5                       6    0.00%       2         4
# 7                    5                       6   20.00%      91         6
# 8                    5                       6   20.00%       6         3
# 9                    5                       6    0.00%      34         5
#
#    Sales  Sales Forecast
# 0    262             392
# 1    732            1096
# 2     15              22
# 3    958            1434
# 4     22              33
# 5     49              73
# 6      7              11
# 7    907            1359
# 8     19              28
# 9    115             172

# %%
# Convertir las columnas de fecha con el formato correcto
df['Order Date'] = pd.to_datetime(df['Order Date'], format="%d/%m/%Y", errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format="%d/%m/%Y", errors='coerce')

# Eliminar el símbolo '%' y convertir a float
df['Discount'] = df['Discount'].str.rstrip('%')  # Asegúrate de usar el nombre correcto de la columna
df['Discount'] = df['Discount'].astype(float) / 100

df['Days to Ship Scheduled'] = df['Days to Ship Scheduled'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                9994 non-null   object
#  1   City                    9994 non-null   object
#  2   Country/Region          9994 non-null   object
#  3   Customer Name           9994 non-null   object
#  4   Order Date              9994 non-null   datetime64[ns]
#  5   Order Profitable?       9994 non-null   object
#  6   Product Name            9994 non-null   object
#  7   Region                  9994 non-null   object
#  8   Segment                 9994 non-null   object
#  9   Ship Date               9994 non-null   datetime64[ns]
#  10  Ship Mode               9994 non-null   object
#  11  Ship Status             9994 non-null   object
#  12  State                   9994 non-null   object
#  13  Sub-Category            9994 non-null   object
#  14  Days to Ship Actual     9994 non-null   int64
#  15  Days to Ship Scheduled  9994 non-null   int64
#  16  Discount                9994 non-null   float64
#  17  Profit                  9994 non-null   int64
#  18  Quantity                9994 non-null   int64
#  19  Sales                   9994 non-null   int64
#  20  Sales Forecast          9994 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(12)
# memory usage: 1.6+ MB

# %%
df.to_csv('../data/superstore_limpio.csv', index=False)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           Category             City Country/Region    Customer Name  \
# 0        Furniture        Henderson  United States      Claire Gute
# 1        Furniture        Henderson  United States      Claire Gute
# 2  Office Supplies      Los Angeles  United States  Darrin Van Huff
# 3        Furniture  Fort Lauderdale  United States   Sean O'Donnell
# 4  Office Supplies  Fort Lauderdale  United States   Sean O'Donnell
#
#   Order Date Order Profitable?  \
# 0 2021-11-08        Profitable
# 1 2021-11-08        Profitable
# 2 2021-06-12        Profitable
# 3 2020-10-11      Unprofitable
# 4 2020-10-11      Unprofitable
#
#                                         Product Name Region    Segment  \
# 0                  Bush Somerset Collection Bookcase  South   Consumer
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  South   Consumer
# 2  Self-Adhesive Address Labels for Typewriters b...   West  Corporate
# 3      Bretford CR4500 Series Slim Rectangular Table  South   Consumer
# 4                     Eldon Fold 'N Roll Cart System  South   Consumer
#
#    Ship Date       Ship Mode      Ship Status       State Sub-Category  \
# 0 2021-11-11    Second Class  Shipped On Time    Kentucky    Bookcases
# 1 2021-11-11    Second Class  Shipped On Time    Kentucky       Chairs
# 2 2021-06-16    Second Class     Shipped Late  California       Labels
# 3 2020-10-18  Standard Class     Shipped Late     Florida       Tables
# 4 2020-10-18  Standard Class     Shipped Late     Florida      Storage
#
#    Days to Ship Actual  Days to Ship Scheduled  Discount  Profit  Quantity  \
# 0                    3                       3      0.00      42         2
# 1                    3                       3      0.00     220         3
# 2                    4                       3      0.00       7         2
# 3                    7                       6      0.45    -383         5
# 4                    7                       6      0.20       3         2
#
#    Sales  Sales Forecast
# 0    262             392
# 1    732            1096
# 2     15              22
# 3    958            1434
# 4     22              33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Category                9994 non-null   object
#  1   City                    9994 non-null   object
#  2   Country/Region          9994 non-null   object
#  3   Customer Name           9994 non-null   object
#  4   Order Date              9994 non-null   datetime64[ns]
#  5   Order Profitable?       9994 non-null   object
#  6   Product Name            9994 non-null   object
#  7   Region                  9994 non-null   object
#  8   Segment                 9994 non-null   object
#  9   Ship Date               9994 non-null   datetime64[ns]
#  10  Ship Mode               9994 non-null   object
#  11  Ship Status             9994 non-null   object
#  12  State                   9994 non-null   object
#  13  Sub-Category            9994 non-null   object
#  14  Days to Ship Actual     9994 non-null   int64
#  15  Days to Ship Scheduled  9994 non-null   int64
#  16  Discount                9994 non-null   float64
#  17  Profit                  9994 non-null   int64
#  18  Quantity                9994 non-null   int64
#  19  Sales                   9994 non-null   int64
#  20  Sales Forecast          9994 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(12)
# memory usage: 1.6+ MB
